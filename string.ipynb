# %%
 # creating a string with single codes
s1='hello'
s1
# Out:
# 'hello'

# %%
# printing a string
print(type(s1))
# Out:
# <class 'str'>

# %%
#creating a string with double codes
s2="world"

# %%
s2
# Out:
# 'world'

# %%
# printing a string
print(type(s2))
# Out:
# <class 'str'>

# %%
#creating a string with triple codes
s3='''pythom is
a programing language'''

# %%
s3
# Out:
# 'pythom is\na programing language'

# %%
#print a triple codes string
print(type(s3))
# Out:
# <class 'str'>

# %%
#contatinating two strings
s4=s1+s2

# %%
s4
# Out:
# 'helloworld'

# %%
s5=s1+' '+s2

# %%
s5
# Out:
# 'hello world'

# %%
#acsesing a string 
s5[0]
# Out:
# 'h'

# %%
s5[10]
# Out:
# 'd'

# %%
#slicing a string
s5[2:8]
# Out:
# 'llo wo'

# %%
#repeating a string 
s5*3
# Out:
# 'hello worldhello worldhello world'

# %%
# check substringd
'world' in s5
# Out:
# True

# %%
'ashal'in s5
# Out:
# False

# %%
'world' not in s5
# Out:
# False

# %%
'ashal' not in s5
# Out:
# True

# %%
#making upper
s5.upper()
# Out:
# 'HELLO WORLD'

# %%
#making lower
s5.lower()
# Out:
# 'hello world'

# %%
s5.capitalize()
# Out:
# 'Hello world'

# %%
#making word first letter capital
s5.title()
# Out:
# 'Hello World'

# %%
#replacing word
s5.replace("world","python")
# Out:
# 'hello python'
