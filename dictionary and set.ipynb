# %%
d1={ }

# %%
d1
# Out:
# {}

# %%
print(type(d1))
# Out:
# <class 'dict'>

# %%
#adding different keys 
d2={'name':'ashal','age':3,'city':'kalpetta'}

# %%
d2
# Out:
# {'name': 'ashal', 'age': 3, 'city': 'kalpetta'}

# %%
#if is phone number if have to put in codes above 9 digits 
person={'name':'ashal','age':18,'city':'kalpetta','phone':'678967845'}

# %%
person
# Out:
# {'name': 'ashal', 'age': 18, 'city': 'kalpetta', 'phone': '678967845'}

# %%
# added a new key value pair
person['salary']=45000

# %%
person
# Out:
# {'name': 'ashal',
#  'age': 18,
#  'city': 'kalpetta',
#  'phone': '678967845',
#  'salary': 45000}

# %%
#updating the key
person['name']='fadi'

# %%
person
# Out:
# {'name': 'fadi',
#  'age': 18,
#  'city': 'kalpetta',
#  'phone': '678967845',
#  'salary': 45000}

# %%
#adding a same key with capital letter 
person['Name']='usman'

# %%
person
# Out:
# {'name': 'fadi',
#  'age': 18,
#  'city': 'kalpetta',
#  'phone': '678967845',
#  'salary': 45000,
#  'Name': 'usman'}

# %%
#deleting the key
del person['Name']

# %%
person
# Out:
# {'name': 'fadi',
#  'age': 18,
#  'city': 'kalpetta',
#  'phone': '678967845',
#  'salary': 45000}

# %%
#acsessing a value with key
person['name']
# Out:
# 'fadi'

# %%
len(person)
# Out:
# 5

# %%
person.keys()
# Out:
# dict_keys(['name', 'age', 'city', 'phone', 'salary'])

# %%
person.values()
# Out:
# dict_values(['fadi', 18, 'kalpetta', '678967845', 45000])

# %%
person.items()
# Out:
# dict_items([('name', 'fadi'), ('age', 18), ('city', 'kalpetta'), ('phone', '678967845'), ('salary', 45000)])

# %% [markdown]
# SET SET SET SET

# %%
# no more duplicates
S1={1,2,3,2,5,1,6,}

# %%
S1
# Out:
# {1, 2, 3, 5, 6}

# %%
s2=set([1,2,1,3,2,3,])

# %%
s2
# Out:
# {1, 2, 3}

# %%
#add a specific digits2.add(5)

# %%
s2
# Out:
# {1, 2, 3, 5}

# %%
#remove a specific digit
s2.remove(3)

# %%
s2
# Out:
# {1, 2, 5}

# %%
#clear all the digits
s2.clear()

# %%
s2
# Out:
# set()

# %%
len(S1)
# Out:
# 5

# %%
s3={11,2,3,4,5,6,7}

# %%
s3
# Out:
# {2, 3, 4, 5, 6, 7, 11}

# %%
S1
# Out:
# {1, 2, 3, 5, 6}

# %%
#union (all elements in both sets but not duplication
s4=s3|S1
s4
# Out:
# {1, 2, 3, 4, 5, 6, 7, 11}

# %%
#common value in a set (intersection
s5=S1&s3
s5
# Out:
# {2, 3, 5, 6}

# %%
#different between sets
s6=S1-s3
s6
# Out:
# {1}

# %%
#differents between sets
s7=s3-S1
s7
# Out:
# {4, 7, 11}
