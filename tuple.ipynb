# %%
#tuple creation
a=(1,2,3,4,)

# %%
a
# Out:
# (1, 2, 3, 4)

# %%
#checking type
print(type(a))
# Out:
# <class 'tuple'>

# %%
b=("lymax",)

# %%
b
# Out:
# ('lymax',)

# %%
print(type(b))
# Out:
# <class 'tuple'>

# %%
#multiple strings
c=("ashal","fadi")

# %%
c
# Out:
# ('ashal', 'fadi')

# %%
#checking type
print(type(c))
# Out:
# <class 'tuple'>

# %%
#tuple with differenet data types
d=("ashal","lymax",1,2,True,False,1.2,2.3)

# %%
d
# Out:
# ('ashal', 'lymax', 1, 2, True, False, 1.2, 2.3)

# %%
#checking type of different datatypes
print(type(d))
# Out:
# <class 'tuple'>

# %%
#checking tuple with out parent ases is also tuple
e=1,2,3,

# %%
e
# Out:
# (1, 2, 3)

# %%
#checking
print(type(e))
# Out:
# <class 'tuple'>

# %%
#merging two tuples
t=a+b
t
# Out:
# (1, 2, 3, 4, 'lymax')

# %%
#multipling tuple with any digit
t1=e*3

# %%
t1
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
#cheching type
print(type(t1))
# Out:
# <class 'tuple'>

# %%
# creating a tuple in a different way
t2=tuple('hello')

# %%
t2
# Out:
# ('h', 'e', 'l', 'l', 'o')

# %%
#checking type
print(type(t2))
# Out:
# <class 'tuple'>

# %%
t2[1]
# Out:
# 'e'

# %%
#versing tuple
t2[::-1]
# Out:
# ('o', 'l', 'l', 'e', 'h')

# %%
#too many value tom unpack
a,b,c,d,=t2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 a,b,c,d,=t2
#
# ValueError: too many values to unpack (expected 4)

# %%
#unpacking tuple
a,b,c,d,e=t2

# %%
a
# Out:
# 'h'

# %%
b
# Out:
# 'e'

# %%
c
# Out:
# 'l'

# %%
d
# Out:
# 'l'

# %%
e
# Out:
# 'o'

# %%
#not enough value to unpack
a,b,c,d,e,f=t2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 a,b,c,d,e,f=t2
#
# ValueError: not enough values to unpack (expected 6, got 5)

# %%
#finding length of tuple
len(t2)
# Out:
# 5

# %%
#item delection not allowed
del t2[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 del t2[1]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
# deledtion complete tuple
del t2
